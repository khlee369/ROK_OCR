ret,thresh2 = cv2.threshold(img,thr,255,cv2.THRESH_BINARY_INV)
    ocr_result = pytesseract.image_to_string(thresh2)
    if show:
        plt.imshow(thresh2, 'gray')
        plt.show()
        print(ocr_result)
    return thresh2, ocr_result

# %%
def str2num(strnum):
    result = strnum.replace(',', '').replace('.', '')
    if result.isdigit():
        return int(result)
    else:
        return 0

# %%
class Player():
    def __init__(self, ID, power, kill):
        self.ID = ID
        self.power = power
        self.kill = kill
        self.name = None
        self.path = None

# %% [markdown]
# # Load id2name.xlsx to dict

# %%
def load_id2name(file_path):
    df_id2name = pd.read_excel(file_path)
    id2name = dict([])

    for i in range(len(df_id2name)):
        row = df_id2name.loc[i]
        id2name[row['ID']] = row['name']
    
    return id2name

# %%
id2name = load_id2name('id2name.xlsx')
id2name
# Out:
# {32858679: '에이치피',
#  32886907: '최Garen',
#  32916567: '민준하은',
#  32888148: '정훈이',
#  32860442: '돌팸환돌',
#  44463382: '앤버는글럿',
#  32881045: '화중군자',
#  34174033: '알몬비',
#  33691098: '으갹으갹갹',
#  32951689: '문마마',
#  32852651: 'GEOEMPIRE',
#  32842266: 'Royal Toi',
#  34068695: 'ccocco',
#  35454450: '앱솔트',
#  34012835: '허세노비',
#  32881241: '전차',
#  32820259: '마리오1023',
#  32878345: '무적금아',
#  32819484: 'JSUB0313',
#  32900080: '뀰뀰',
#  33334611: '명세지재',
#  33898594: '고오니아빠',
#  32910924: '인수성',
#  33984315: 'TOYFLY',
#  34011747: 'Dondekman',
#  32878596: 'coreanito26',
#  32904134: 'llii0993',
#  32947520: '알파카조앙',
#  32889863: '륭입니다',
#  32873041: '꿈도없다',
#  32858701: 'aquagu',
#  33963794: '수라비',
#  32870013: '섭리',
#  32921831: 'TGG밀크커피',
#  32850372: '킹갓권율',
#  33995797: 'ALOHABIN',
#  34027799: '썁새끼',
#  34344247: '운동하자',
#  32818701: 'kdc0627',
#  33264554: 'TOP신상25',
#  32886302: '파괴본능',
#  32866794: '소혼시후',
#  32916643: '람겸',
#  34015869: '독고구천검',
#  32909658: '다혜나라',
#  32850382: 'NO ABE',
#  32871044: 'N2coni',
#  32908249: '아나머',
#  32911721: '히니',
#  32937381: '큰연못',
#  32865578: '뚠뚠월드',
#  32889186: 'DP kakei',
#  37268288: '신승용1997',
#  35508783: '노호자',
#  32824512: '젠트리',
#  32937876: 'TOP랄랄랄라',
#  32939826: '퀴리 마리',
#  32931677: '1812L',
#  39715543: '신난스티치',
#  32899091: 'jeehoney',
#  32921203: '기짝',
#  34001747: '고투덩실',
#  34035160: 'LordMohmmed',
#  36892658: '욱그리거',
#  32905501: 'HDST훈블리',
#  35650857: '영양아구',
#  32895911: 'castlejun',
#  37796819: '붉은물결',
#  34568871: '빅보스',
#  32916321: 'DONMELCHOR',
#  52207379: 'WestUK',
#  53114051: '정동생',
#  60143585: '국뽕탱이',
#  32875812: 'Dalredal',
#  63002044: '이천산적',
#  32904825: '끄로바군주',
#  32915466: '노래하는 허브',
#  63270437: '김건빵2',
#  49497280: 'DreamMart',
#  64094946: '윤성뭉',
#  69419248: '늠선생',
#  32914780: '방범대원',
#  32921102: '6072리',
#  33003834: '노마',
#  32948675: '조시안서',
#  34000149: '초록별공공',
#  32944092: '유로',
#  32858136: '폭풍청산',
#  32904056: '828 K9',
#  32877848: '농사꾼메데',
#  32892748: '빠삐장군',
#  32885285: '폭풍날먹',
#  32901235: '자한당멸망',
#  34882192: '최강장수',
#  32873061: '아스라',
#  42395617: '세그마',
#  38003357: '유니지갑',
#  35658838: '강백호',
#  42193164: '국제공항2',
#  38066976: '바다검',
#  41805300: '화중군자금',
#  42547043: '메구리',
#  56796484: '야루루루',
#  42546537: '키라라 아스카',
#  42482910: 'GERENT0T',
#  55222825: '우헤아라 아이',
#  52115995: 'Dream공산팀',
#  55223781: '하마사키 마오',
#  68575684: '똥꼬가스랄여서오그리마'}

# %% [markdown]
# # Let's OCR

# %%
Players = dict([])

L = len(profile_list)
for i, fn in enumerate(profile_list):
    print('{}/{}'.format(i,L))
    img = cv2.imread(fn,0)

    IDp = crop_dict['ID']
    powerp = crop_dict['power']
    killp = crop_dict['kill']
    
    img_ID = img[IDp[0]:IDp[1], IDp[2]:IDp[3]]
    img_power = img[powerp[0]:powerp[1], powerp[2]:powerp[3]]
    img_kill = img[killp[0]:killp[1], killp[2]:killp[3]]
    
    _, str_ID = bin_inv(img_ID)
    _, str_power = bin_inv(img_power)
    _, str_kill = bin_inv(img_kill)
    
    ID, power, kill = str2num(str_ID), str2num(str_power), str2num(str_kill)
    
    Players[ID] = Player(ID,power,kill)        
    Players[ID].path = fn.split('\\')[-1]
    
    try:
        Players[ID].name = id2name[ID]
    except KeyError:
        print('KeyError!! : checkt {}'.format(Players[ID].path))
        Players[ID].name = ''
# Out:
# 0/133
# KeyError!! : checkt Screenshot_2020-07-21-02-59-36.png
# 1/133
# KeyError!! : checkt Screenshot_2020-07-21-02-59-43.png
# 2/133
# KeyError!! : checkt Screenshot_2020-07-21-02-59-48.png
# 3/133
# KeyError!! : checkt Screenshot_2020-07-21-02-59-53.png
# 4/133
# KeyError!! : checkt Screenshot_2020-07-21-02-59-58.png
# 5/133
# KeyError!! : checkt Screenshot_2020-07-21-03-00-04.png
# 6/133
# KeyError!! : checkt Screenshot_2020-07-21-03-00-09.png
# 7/133
# KeyError!! : checkt Screenshot_2020-07-21-03-27-27.png
# 8/133
# 9/133
# 10/133
# KeyError!! : checkt Screenshot_2020-07-21-03-27-47.png
# 11/133
# 12/133
# 13/133
# 14/133
# 15/133
# 16/133
# KeyError!! : checkt Screenshot_2020-07-21-03-28-26.png
# 17/133
# KeyError!! : checkt Screenshot_2020-07-21-03-28-33.png
# 18/133
# 19/133
# 20/133
# 21/133
# KeyError!! : checkt Screenshot_2020-07-21-03-28-57.png
# 22/133
# 23/133
# 24/133
# 25/133
# 26/133
# KeyError!! : checkt Screenshot_2020-07-21-03-29-32.png
# 27/133
# 28/133
# 29/133
# 30/133
# 31/133
# 32/133
# 33/133
# KeyError!! : checkt Screenshot_2020-07-21-03-30-18.png
# 34/133
# KeyError!! : checkt Screenshot_2020-07-21-03-30-25.png
# 35/133
# 36/133
# 37/133
# 38/133
# 39/133
# 40/133
# 41/133
# 42/133
# 43/133
# 44/133
# 45/133
# 46/133
# KeyError!! : checkt Screenshot_2020-07-21-03-31-42.png
# 47/133
# 48/133
# 49/133
# 50/133
# 51/133
# 52/133
# KeyError!! : checkt Screenshot_2020-07-21-03-32-23.png
# 53/133
# 54/133
# 55/133
# 56/133
# 57/133
# 58/133
# 59/133
# 60/133
# 61/133
# KeyError!! : checkt Screenshot_2020-07-21-03-33-22.png
# 62/133
# 63/133
# 64/133
# 65/133
# 66/133
# 67/133
# 68/133
# KeyError!! : checkt Screenshot_2020-07-21-03-34-13.png
# 69/133
# 70/133
# 71/133
# 72/133
# 73/133
# 74/133
# 75/133
# 76/133
# 77/133
# 78/133
# 79/133
# 80/133
# 81/133
# 82/133
# 83/133
# 84/133
# 85/133
# 86/133
# 87/133
# 88/133
# 89/133
# 90/133
# 91/133
# 92/133
# 93/133
# 94/133
# 95/133
# 96/133
# 97/133
# 98/133
# 99/133
# 100/133
# 101/133
# 102/133
# 103/133
# 104/133
# 105/133
# 106/133
# 107/133
# 108/133
# 109/133
# KeyError!! : checkt Screenshot_2020-07-21-03-38-49.png
# 110/133
# 111/133
# KeyError!! : checkt Screenshot_2020-07-21-03-39-09.png
# 112/133
# 113/133
# KeyError!! : checkt Screenshot_2020-07-21-03-39-22.png
# 114/133
# 115/133
# KeyError!! : checkt Screenshot_2020-07-21-03-39-34.png
# 116/133
# 117/133
# KeyError!! : checkt Screenshot_2020-07-21-03-39-46.png
# 118/133
# KeyError!! : checkt Screenshot_2020-07-21-03-39-52.png
# 119/133
# KeyError!! : checkt Screenshot_2020-07-21-03-39-58.png
# 120/133
# KeyError!! : checkt Screenshot_2020-07-21-03-40-05.png
# 121/133
# KeyError!! : checkt Screenshot_2020-07-21-03-40-11.png
# 122/133
# 123/133
# 124/133
# KeyError!! : checkt Screenshot_2020-07-21-03-40-32.png
# 125/133
# 126/133
# 127/133
# 128/133
# 129/133
# 130/133
# 131/133
# 132/133

# %%
df = {
    'ID' : [],
    'name' : [],
    'power' : [],
    'kill' : [],
    'path' : []
}
df = pd.DataFrame(df, dtype=int)

L = len(Players)
for ID, p in Players.items():
    df = df.append({
        'ID' : ID,
        'name' : p.name,
        'power' : p.power,
        'kill' : p.kill,
        'path' : p.path
    }, ignore_index=True)

# %%
df
# Out:
#            ID         name      power       kill  \
# 0    32963004               111024771   61069693
# 1    32864188                51423715    7112259
# 2    36954744                62497516   11617124
# 3    32930660                50937003    4202652
# 4    32928689                86041955  115792742
# ..        ...          ...        ...        ...
# 117  42547043          메구리    1957670      30845
# 118  42482910     GERENT0T    1022609          0
# 119  55222825      우헤아라 아이     849942        332
# 120  68575684  똥꼬가스랄여서오그리마     416766          0
# 121  55223781      하마사키 마오     819326          0
#
#                                    path
# 0    Screenshot_2020-07-21-02-59-36.png
# 1    Screenshot_2020-07-21-02-59-43.png
# 2    Screenshot_2020-07-21-02-59-48.png
# 3    Screenshot_2020-07-21-02-59-53.png
# 4    Screenshot_2020-07-21-02-59-58.png
# ..                                  ...
# 117  Screenshot_2020-07-21-03-40-57.png
# 118  Screenshot_2020-07-21-03-41-03.png
# 119  Screenshot_2020-07-21-03-41-09.png
# 120  Screenshot_2020-07-21-03-41-15.png
# 121  Screenshot_2020-07-21-03-41-21.png
#
# [122 rows x 5 columns]

# %% [markdown]
# # save as xlsx

# %%
dt = datetime.datetime.now()
output_name = '-'.join([str(dt.year), str(dt.month), str(dt.day)])
output_name = 'PALO-' + output_name

# %%
df.to_excel(output_name + '.xlsx', index=False)

# %% [markdown]
# # ------------------------------------

# %% [markdown]
# # id2name 만들기

# %%
# 기존 파일 load
id2name = load_id2name('id2name.xlsx')
id2name
# Out:
# {32858679: '에이치피',
#  32886907: '최Garen',
#  32916567: '민준하은',
#  32888148: '정훈이',
#  32860442: '돌팸환돌',
#  44463382: '앤버는글럿',
#  32881045: '화중군자',
#  34174033: '알몬비',
#  33691098: '으갹으갹갹',
#  32951689: '문마마',
#  32852651: 'GEOEMPIRE',
#  32842266: 'Royal Toi',
#  34068695: 'ccocco',
#  35454450: '앱솔트',
#  34012835: '허세노비',
#  32881241: '전차',
#  32820259: '마리오1023',
#  32878345: '무적금아',
#  32819484: 'JSUB0313',
#  32900080: '뀰뀰',
#  33334611: '명세지재',
#  33898594: '고오니아빠',
#  32910924: '인수성',
#  33984315: 'TOYFLY',
#  34011747: 'Dondekman',
#  32878596: 'coreanito26',
#  32904134: 'llii0993',
#  32947520: '알파카조앙',
#  32889863: '륭입니다',
#  32873041: '꿈도없다',
#  32858701: 'aquagu',
#  33963794: '수라비',
#  32870013: '섭리',
#  32921831: 'TGG밀크커피',
#  32850372: '킹갓권율',
#  33995797: 'ALOHABIN',
#  34027799: '썁새끼',
#  34344247: '운동하자',
#  32818701: 'kdc0627',
#  33264554: 'TOP신상25',
#  32886302: '파괴본능',
#  32866794: '소혼시후',
#  32916643: '람겸',
#  34015869: '독고구천검',
#  32909658: '다혜나라',
#  32850382: 'NO ABE',
#  32871044: 'N2coni',
#  32908249: '아나머',
#  32911721: '히니',
#  32937381: '큰연못',
#  32865578: '뚠뚠월드',
#  32889186: 'DP kakei',
#  37268288: '신승용1997',
#  35508783: '노호자',
#  32824512: '젠트리',
#  32937876: 'TOP랄랄랄라',
#  32939826: '퀴리 마리',
#  32931677: '1812L',
#  39715543: '신난스티치',
#  32899091: 'jeehoney',
#  32921203: '기짝',
#  34001747: '고투덩실',
#  34035160: 'LordMohmmed',
#  36892658: '욱그리거',
#  32905501: 'HDST훈블리',
#  35650857: '영양아구',
#  32895911: 'castlejun',
#  37796819: '붉은물결',
#  34568871: '빅보스',
#  32916321: 'DONMELCHOR',
#  52207379: 'WestUK',
#  53114051: '정동생',
#  60143585: '국뽕탱이',
#  32875812: 'Dalredal',
#  63002044: '이천산적',
#  32904825: '끄로바군주',
#  32915466: '노래하는 허브',
#  63270437: '김건빵2',
#  49497280: 'DreamMart',
#  64094946: '윤성뭉',
#  69419248: '늠선생',
#  32914780: '방범대원',
#  32921102: '6072리',
#  33003834: '노마',
#  32948675: '조시안서',
#  34000149: '초록별공공',
#  32944092: '유로',
#  32858136: '폭풍청산',
#  32904056: '828 K9',
#  32877848: '농사꾼메데',
#  32892748: '빠삐장군',
#  32885285: '폭풍날먹',
#  32901235: '자한당멸망',
#  34882192: '최강장수',
#  32873061: '아스라',
#  42395617: '세그마',
#  38003357: '유니지갑',
#  35658838: '강백호',
#  42193164: '국제공항2',
#  38066976: '바다검',
#  41805300: '화중군자금',
#  42547043: '메구리',
#  56796484: '야루루루',
#  42546537: '키라라 아스카',
#  42482910: 'GERENT0T',
#  55222825: '우헤아라 아이',
#  52115995: 'Dream공산팀',
#  55223781: '하마사키 마오',
#  68575684: '똥꼬가스랄여서오그리마'}

# %%
newID = 'PALO-2020-7-21.xlsx'

df_id2name = pd.read_excel(newID)
for i in range(len(df_id2name)):
    df_row = df_id2name.loc[i]
    if type(df_row['name']) is not str:
        id2name[df_row['ID']] = ''
    else:
        id2name[df_row['ID']] = df_row['name']

# %%
id2name
# Out:
# {32858679: '에이치피',
#  32886907: '최Garen',
#  32916567: '민준하은',
#  32888148: '정훈이',
#  32860442: '돌팸환돌',
#  44463382: '앤버는글럿',
#  32881045: '화중군자',
#  34174033: '알몬비',
#  33691098: '으갹으갹갹',
#  32951689: '문마마',
#  32852651: 'GEOEMPIRE',
#  32842266: 'Royal Toi',
#  34068695: 'ccocco',
#  35454450: '앱솔트',
#  34012835: '허세노비',
#  32881241: '전차',
#  32820259: '마리오1023',
#  32878345: '무적금아',
#  32819484: 'JSUB0313',
#  32900080: '뀰뀰',
#  33334611: '명세지재',
#  33898594: '고오니아빠',
#  32910924: '인수성',
#  33984315: 'TOYFLY',
#  34011747: 'Dondekman',
#  32878596: 'coreanito26',
#  32904134: 'llii0993',
#  32947520: '알파카조앙',
#  32889863: '륭입니다',
#  32873041: '꿈도없다',
#  32858701: 'aquagu',
#  33963794: '수라비',
#  32870013: '섭리',
#  32921831: 'TGG밀크커피',
#  32850372: '킹갓권율',
#  33995797: 'ALOHABIN',
#  34027799: '썁새끼',
#  34344247: '운동하자',
#  32818701: 'kdc0627',
#  33264554: 'TOP신상25',
#  32886302: '파괴본능',
#  32866794: '소혼시후',
#  32916643: '람겸',
#  34015869: '독고구천검',
#  32909658: '다혜나라',
#  32850382: 'NO ABE',
#  32871044: 'N2coni',
#  32908249: '아나머',
#  32911721: '히니',
#  32937381: '큰연못',
#  32865578: '뚠뚠월드',
#  32889186: 'DP kakei',
#  37268288: '신승용1997',
#  35508783: '노호자',
#  32824512: '젠트리',
#  32937876: 'TOP랄랄랄라',
#  32939826: '퀴리 마리',
#  32931677: '1812L',
#  39715543: '신난스티치',
#  32899091: 'jeehoney',
#  32921203: '기짝',
#  34001747: '고투덩실',
#  34035160: 'LordMohmmed',
#  36892658: '욱그리거',
#  32905501: 'HDST훈블리',
#  35650857: '영양아구',
#  32895911: 'castlejun',
#  37796819: '붉은물결',
#  34568871: '빅보스',
#  32916321: 'DONMELCHOR',
#  52207379: 'WestUK',
#  53114051: '정동생',
#  60143585: '국뽕탱이',
#  32875812: 'Dalredal',
#  63002044: '이천산적',
#  32904825: '끄로바군주',
#  32915466: '노래하는 허브',
#  63270437: '김건빵2',
#  49497280: 'DreamMart',
#  64094946: '윤성뭉',
#  69419248: '늠선생',
#  32914780: '방범대원',
#  32921102: '6072리',
#  33003834: '노마',
#  32948675: '조시안서',
#  34000149: '초록별공공',
#  32944092: '유로',
#  32858136: '폭풍청산',
#  32904056: '828 K9',
#  32877848: '농사꾼메데',
#  32892748: '빠삐장군',
#  32885285: '폭풍날먹',
#  32901235: '자한당멸망',
#  34882192: '최강장수',
#  32873061: '아스라',
#  42395617: '세그마',
#  38003357: '유니지갑',
#  35658838: '강백호',
#  42193164: '국제공항2',
#  38066976: '바다검',
#  41805300: '화중군자금',
#  42547043: '메구리',
#  56796484: '야루루루',
#  42546537: '키라라 아스카',
#  42482910: 'GERENT0T',
#  55222825: '우헤아라 아이',
#  52115995: 'Dream공산팀',
#  55223781: '하마사키 마오',
#  68575684: '똥꼬가스랄여서오그리마',
#  32963004: '폭풍검',
#  32864188: '찬사',
#  36954744: '불곰',
#  32930660: '폭풍을지',
#  32928689: '외돌',
#  32949515: '물돌',
#  37061883: '태랑노군',
#  33161683: '시미켄',
#  32849136: '유니파더손',
#  32934708: '6사염화9',
#  34023817: '아야루',
#  32997413: 'DB베지터',
#  32838380: 'Robin Since87',
#  34352176: '폭풍헬퍼',
#  34014496: '베이비',
#  32852288: '설거지',
#  42322165: 'FTTS플라이하이',
#  32880341: '혀니비나',
#  69900353: '빈꼬끄',
#  39738082: '수정',
#  32877496: '꼬따발',
#  32931643: '폭풍JOKER',
#  32869646: '꽃돌',
#  32958563: '와이핀',
#  36654814: '뉴비',
#  32890539: '헌터',
#  33154600: '악돌',
#  36466625: '오구라 유나'}

# %% [markdown]
# # dict to xlsx

# %%
df_xlsx = {
    'ID' : [],
    'name' : [],
}
df_xlsx = pd.DataFrame(df_xlsx, dtype=int)

for ID, name in id2name.items():
    df_xlsx = df_xlsx.append({
        'ID' : ID,
        'name' : name
    }, ignore_index=True)
    
df_xlsx.to_excel('id2name_tmp.xlsx', index=False)

# %% [markdown]
# # ALL

# %%
# for fn in profile_list:
#     img = cv2.imread(fn,0)
#     plt.imshow(img, 'gray')
#     plt.show()

#     IDp = crop_dict['ID']
#     powerp = crop_dict['power']
#     killp = crop_dict['kill']
    
#     img_ID = img[IDp[0]:IDp[1], IDp[2]:IDp[3]]
#     img_power = img[powerp[0]:powerp[1], powerp[2]:powerp[3]]
#     img_kill = img[killp[0]:killp[1], killp[2]:killp[3]]
    
#     i1 = bin_inv(img_ID, show=True)
#     i2 = bin_inv(img_power, show=True)
#     i3 = bin_inv(img_kill, show=True)
    

#     a = input('y or n')
#     if a == 'n':
#         break
