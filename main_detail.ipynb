# %%
from rok_launcher import NoxManager

import OCRHelper as OH
import datetime
import glob

config = {
    'nox_size' : (720, 1280)
}
# Out:
# Loaded id2name.xlsx as id2name
# Loaded id2name.xlsx as id2name

# %% [markdown]
# # Get Nox Screen

# %%
manager = NoxManager(config=config, verbose=False)

# %% [markdown]
# # Capture All Members

# %%
# 타연맹일경우 other = True
# 자연맹일경우 other = False
manager.capture_members_all(other=False, detail=True)

# %% [markdown]
# # Let's OCR

# %%
# OCRHelper.py 에서 profile_list를 initialize 하려 했으나
# import 와 동시에 profile_list가 eval되어 빈폴더를 load하는 문제가 발생
profile_path = './Screenshots/'
profile_list = glob.glob(profile_path + '*.png')
Players = OH.ocr_profiles_detail(profile_list = profile_list)
# Out:
# 1/226 : profile processing
# 2/226 : detail processing
# 3/226 : profile processing
# 4/226 : detail processing
# 5/226 : profile processing
# 6/226 : detail processing
# 7/226 : profile processing
# 8/226 : detail processing
# 9/226 : profile processing
# 10/226 : detail processing
# 11/226 : profile processing
# 12/226 : detail processing
# 13/226 : profile processing
# 14/226 : detail processing
# 15/226 : profile processing
# 16/226 : detail processing
# 17/226 : profile processing
# 18/226 : detail processing
# 19/226 : profile processing
# 20/226 : detail processing
# 21/226 : profile processing
# 22/226 : detail processing
# 23/226 : profile processing
# 24/226 : detail processing
# 25/226 : profile processing
# 26/226 : detail processing
# 27/226 : profile processing
# 28/226 : detail processing
# 29/226 : profile processing
# 30/226 : detail processing
# 31/226 : profile processing
# 32/226 : detail processing
# 33/226 : profile processing
# 34/226 : detail processing
# 35/226 : profile processing
# 36/226 : detail processing
# 37/226 : profile processing
# 38/226 : detail processing
# 39/226 : profile processing
# 40/226 : detail processing
# 41/226 : profile processing
# 42/226 : detail processing
# 43/226 : profile processing
# 44/226 : detail processing
# 45/226 : profile processing
# 46/226 : detail processing
# 47/226 : profile processing
# 48/226 : detail processing
# 49/226 : profile processing
# 50/226 : detail processing
# 51/226 : profile processing
# 52/226 : detail processing
# 53/226 : profile processing
# 54/226 : detail processing
# 55/226 : profile processing
# 56/226 : detail processing
# 57/226 : profile processing
# 58/226 : detail processing
# 59/226 : profile processing
# 60/226 : detail processing
# 61/226 : profile processing
# 62/226 : detail processing
# 63/226 : profile processing
# 64/226 : detail processing
# 65/226 : profile processing
# 66/226 : detail processing
# 67/226 : profile processing
# 68/226 : detail processing
# 69/226 : profile processing
# 70/226 : detail processing
# 71/226 : profile processing
# 72/226 : detail processing
# 73/226 : profile processing
# 74/226 : detail processing
# 75/226 : profile processing
# 76/226 : detail processing
# 77/226 : profile processing
# 78/226 : detail processing
# 79/226 : profile processing
# 80/226 : detail processing
# 81/226 : profile processing
# 82/226 : detail processing
# 83/226 : profile processing
# 84/226 : detail processing
# 85/226 : profile processing
# 86/226 : detail processing
# 87/226 : profile processing
# 88/226 : detail processing
# 89/226 : profile processing
# 90/226 : detail processing
# 91/226 : profile processing
# 92/226 : detail processing
# 93/226 : profile processing
# 94/226 : detail processing
# 95/226 : profile processing
# 96/226 : detail processing
# 97/226 : profile processing
# 98/226 : detail processing
# 99/226 : profile processing
# 100/226 : detail processing
# 101/226 : profile processing
# 102/226 : detail processing
# 103/226 : profile processing
# 104/226 : detail processing
# 105/226 : profile processing
# 106/226 : detail processing
# 107/226 : profile processing
# 108/226 : detail processing
# 109/226 : profile processing
# 110/226 : detail processing
# 111/226 : profile processing
# 112/226 : detail processing
# 113/226 : profile processing
# 114/226 : detail processing
# 115/226 : profile processing
# 116/226 : detail processing
# 117/226 : profile processing
# 118/226 : detail processing
# 119/226 : profile processing
# 120/226 : detail processing
# 121/226 : profile processing
# 122/226 : detail processing
# 123/226 : profile processing
# 124/226 : detail processing
# 125/226 : profile processing
# 126/226 : detail processing
# 127/226 : profile processing
# 128/226 : detail processing
# 129/226 : profile processing
# 130/226 : detail processing
# 131/226 : profile processing
# 132/226 : detail processing
# 133/226 : profile processing
# 134/226 : detail processing
# 135/226 : profile processing
# 136/226 : detail processing
# 137/226 : profile processing
# 138/226 : detail processing
# 139/226 : profile processing
# 140/226 : detail processing
# 141/226 : profile processing
# 142/226 : detail processing
# 143/226 : profile processing
# 144/226 : detail processing
# 145/226 : profile processing
# 146/226 : detail processing
# 147/226 : profile processing
# 148/226 : detail processing
# 149/226 : profile processing
# 150/226 : detail processing
# 151/226 : profile processing
# 152/226 : detail processing
# 153/226 : profile processing
# 154/226 : detail processing
# 155/226 : profile processing
# 156/226 : detail processing
# 157/226 : profile processing
# 158/226 : detail processing
# 159/226 : profile processing
# 160/226 : detail processing
# 161/226 : profile processing
# 162/226 : detail processing
# 163/226 : profile processing
# 164/226 : detail processing
# 165/226 : profile processing
# 166/226 : detail processing
# 167/226 : profile processing
# 168/226 : detail processing
# 169/226 : profile processing
# 170/226 : detail processing
# 171/226 : profile processing
# 172/226 : detail processing
# 173/226 : profile processing
# 174/226 : detail processing
# 175/226 : profile processing
# 176/226 : detail processing
# 177/226 : profile processing
# 178/226 : detail processing
# 179/226 : profile processing
# 180/226 : detail processing
# 181/226 : profile processing
# 182/226 : detail processing
# 183/226 : profile processing
# 184/226 : detail processing
# 185/226 : profile processing
# 186/226 : detail processing
# 187/226 : profile processing
# 188/226 : detail processing
# 189/226 : profile processing
# 190/226 : detail processing
# 191/226 : profile processing
# 192/226 : detail processing
# 193/226 : profile processing
# 194/226 : detail processing
# 195/226 : profile processing
# 196/226 : detail processing
# 197/226 : profile processing
# 198/226 : detail processing
# 199/226 : profile processing
# 200/226 : detail processing
# 201/226 : profile processing
# 202/226 : detail processing
# 203/226 : profile processing
# 204/226 : detail processing
# 205/226 : profile processing
# 206/226 : detail processing
# 207/226 : profile processing
# 208/226 : detail processing
# 209/226 : profile processing
# 210/226 : detail processing
# 211/226 : profile processing
# 212/226 : detail processing
# 213/226 : profile processing
# 214/226 : detail processing
# 215/226 : profile processing
# 216/226 : detail processing
# 217/226 : profile processing
# 218/226 : detail processing
# 219/226 : profile processing
# 220/226 : detail processing
# 221/226 : profile processing
# 222/226 : detail processing
# 223/226 : profile processing
# 224/226 : detail processing
# 225/226 : profile processing
# 226/226 : detail processing

# %% [markdown]
# # Convert to DataFrame

# %%
df = OH.Players2df_detail(Players)
df
# Out:
#            ID         name     power     kill  kill_4T  kill_5T   death  \
# 0    33161683          시미켄  43538461  8472495  2890719   361157  458591
# 1    32858679         에이치피  39932235  1448263   620523    93634  306878
# 2    32886907       최Garen  39474562  2487123   808557    48472  600447
# 3    32849136        유니파더손  38634507  2323839   788177   125866  196871
# 4    32916567         민준하은  36930657  3422130  1268810   100256  693065
# ..        ...          ...       ...      ...      ...      ...     ...
# 100  55222825      우헤아라 아이    985417      332      332        0       0
# 101  55223781      하마사키 마오    959120        0        0        0       0
# 102  64937177     요시자와 아키호    272766        0        0        0       0
# 103  68575684  똥꼬가스랄여서오그리마    500744        0        0        0       0
# 104  46545957       찬사(부캐)    160439        0        0        0       0
#
#       gathering      assist                                path
# 0    4689362185  1171008127  Screenshot_2020-08-13-01-40-42.png
# 1    5995362024   482977082  Screenshot_2020-08-13-01-40-53.png
# 2    4307806687    16000000  Screenshot_2020-08-13-01-41-01.png
# 3    5651778188    31056417  Screenshot_2020-08-13-01-41-09.png
# 4    4832375433   474350080  Screenshot_2020-08-13-01-41-18.png
# ..          ...         ...                                 ...
# 100   184461177   212475369  Screenshot_2020-08-13-01-52-36.png
# 101   189221376   213168078  Screenshot_2020-08-13-01-52-42.png
# 102     3537492           0  Screenshot_2020-08-13-01-52-48.png
# 103    25103424           0  Screenshot_2020-08-13-01-52-53.png
# 104     1886185           0  Screenshot_2020-08-13-01-52-59.png
#
# [105 rows x 10 columns]

# %% [markdown]
# # Save as xlsx

# %%
dt = datetime.datetime.now()
output_name = '-'.join([str(dt.year), str(dt.month), str(dt.day)])
output_name = 'PLO2-' + output_name + '-detail'
df.to_excel(output_name + '.xlsx', index=False)

# %% [markdown]
# # Expand id2name
#
# OCR후 저장된 xlsx file(e.g. df.to_excel(output_name + '.xlsx', index=False))를 open합니다. name이 빠져있는 id를 체크하여 name을 채워넣습니다. 그 후 다음 코드를 실행하세요.

# %%
# id2name = OH.load_id2name('PALO-2020-7-21.xlsx', 
#                           id2name=OH.load_id2name('id2name.xlsx'))
# id2name

# %%
# OH.save_id2name(id2name)
