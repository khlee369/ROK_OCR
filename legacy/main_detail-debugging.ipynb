# %%
from rok_launcher import NoxManager

import OCRHelper as OH
import datetime
import glob

config = {
    'nox_size' : (720, 1280)
}
# Out:
# Loaded id2name.xlsx as id2name
# Loaded id2name.xlsx as id2name

# %% [markdown]
# # Get Nox Screen

# %%
manager = NoxManager(config=config, verbose=False)
# Out:
# -------------------------------------
# Run Nox Application and Press Any Key
# Now Find Nox Position
#
#
# Refining Nox Position
#
#
# Finished

# %%
from configs import *
from util import *
import cv2
import matplotlib.pyplot as plt

# %%
manager.get_relative_pos(img_dict['R1'])
# Out:
# (array([262, 200]), 0.01576435836777567)

# %%
screen = get_screen(manager.sct, manager.rank_monitor)
R1_pos, R1_diff = find_img_pos(screen, cv2.imread(img_dict['R1']),
                               interval=2, offset=rank_offset)
print(R1_pos)
print(R1_diff)
# Out:
# [242 178]
# 0.015178778273240353

# %%
manager.get_relative_mouse_pos()
# Out:
# array([644, 173])

# %%
manager.nox_monitor

# %%
manager.capture_monitor

# %%
rank_monitor = manager.nox_monitor.copy()
rank_monitor['left'] += 160
rank_monitor['top'] += 220
rank_monitor['width'] = 80
rank_monitor['height'] = 480

# %%
screen = get_screen(manager.sct, rank_monitor)
img = cv2.imread(img_dict['R3'])
pos, diff = find_img_pos(screen, img, interval=2)
print(pos)
print(diff)

print(pos + (100, 200))

# %%
manager.get_relative_pos(img_dict['R3'])

# %%
plt.figure(figsize=(10,10))
plt.imshow(get_screen(manager.sct, rank_monitor))

# %%
[220, 180], [710, 230]

# %%
plt.imshow(cv2.imread(img_dict['R2']))

# %%
manager.get_relative_mouse_pos()

# %%
manager.get_relative_mouse_pos()

# %%
plt.imshow(get_screen(manager.sct, manager.nox_monitor))

# %% [markdown]
# # Capture All Members

# %%
img = cv2.imread(img_dict['R3'])
screen = get_screen(manager.sct, manager.nox_monitor)
find_img_pos(screen, img)

# %%
manager.get_relative_pos(img_dict['R3'])

# %%
manager.get_relative_pos(img_dict['R2'])

# %%
manager.get_relative_pos(img_dict['R1'])

# %%
manager.get_relative_mouse_pos()

# %%
manager.get_relative_pos(img_dict['R3'])

# %%
manager.get_relative_pos(img_dict['R2'])

# %%
manager.get_relative_pos(img_dict['R1'])

# %%
manager.get_relative_mouse_pos()

# %%
try:
    None - None
except TypeError:
    print('hi')

# %%
None - None

# %%
manager.capture_R3()

# %%
manager.capture_leader(detail=True)

# %%
manager.capture_R4(detail=True)

# %%
manager.capture_R3(detail=True, dragged=True)

# %%
manager.capture_R2(detail=True)

# %%
# 타연맹일경우 other = True
# 자연맹일경우 other = False
manager.capture_members_all(other=False, detail=True)

# %% [markdown]
# # Let's OCR

# %%
# OCRHelper.py 에서 profile_list를 initialize 하려 했으나
# import 와 동시에 profile_list가 eval되어 빈폴더를 load하는 문제가 발생
profile_path = './Screenshots/'
profile_list = glob.glob(profile_path + '*.png')
Players = OH.ocr_profiles_detail(profile_list = profile_list)

# %% [markdown]
# # Convert to DataFrame

# %%
df = OH.Players2df_detail(Players)
df

# %% [markdown]
# # Save as xlsx

# %%
dt = datetime.datetime.now()
output_name = '-'.join([str(dt.year), str(dt.month), str(dt.day)])
output_name = 'ERS-' + output_name + '-detail'
df.to_excel(output_name + '.xlsx', index=False)

# %% [markdown]
# # Expand id2name
#
# OCR후 저장된 xlsx file(e.g. df.to_excel(output_name + '.xlsx', index=False))를 open합니다. name이 빠져있는 id를 체크하여 name을 채워넣습니다. 그 후 다음 코드를 실행하세요.

# %%
id2name = OH.load_id2name('ERH-2020-8-24-detail.xlsx', 
                          id2name=OH.load_id2name('id2name.xlsx'))
id2name

# %%
OH.save_id2name(id2name)
