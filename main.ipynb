# %%
from rok_launcher import NoxManager

import OCRHelper as OH
import datetime
import glob

config = {
    'nox_size' : (720, 1280)
}

import time
# Out:
# Loaded id2name.xlsx as id2name
# Loaded id2name.xlsx as id2name

# %% [markdown]
# # Get Nox Screen

# %%
manager = NoxManager(config=config, verbose=False)
# Out:
# -------------------------------------
# Run Nox Application and Press Any Key
# Now Find Nox Position
#
#
# Refining Nox Position
#
#
# Finished

# %% [markdown]
# # Capture All Members

# %% [markdown]
# # 3급, 2급, 1급 연맹원 수가 12(16일수도?)명 이하면 드래그가 제대로 되지 않아 클릭미스가 남

# %%
manager.capture_leader(other=True)

# %%
manager.capture_R4(other=True)

# %%
manager.capture_R2(other=True)

# %%
manager.capture_R1(other=True)

# %%
# 타연맹일경우 other = True
# 자연맹일경우 other = False
manager.capture_members_all(other=True)
# Out:
# ------------------------------------------
# Run Rise of Kingdoms and Open the menu to show alliance tab
#
# Click members tab to show members
#
# Open side bar of nox player to show captuer icon
# ------------------------------------------
# Now start to capture
# profile_diff:  0.013615923475576708
# CAPTURE!
# CAN NOT FIND CAPTURE, OPENING NOX MENU
# profile_diff:  0.012674563395453687
# CAPTURE!
# profile_diff:  0.011101420340188399
# CAPTURE!
# profile_diff:  0.011341732440938708
# CAPTURE!
# profile_diff:  0.014754695584781086
# CAPTURE!
# profile_diff:  0.014842466092371599
# CAPTURE!
# profile_diff:  0.012203156907982833
# CAPTURE!
# profile_diff:  0.008705755285328009
# CAPTURE!
# profile_diff:  0.011844360302705753
# CAPTURE!
# profile_diff:  0.012334370561160126
# CAPTURE!
# profile_diff:  0.008672104949819345
# CAPTURE!
# profile_diff:  0.01314359264590354
# CAPTURE!
# profile_diff:  0.015120176596794665
# CAPTURE!
# profile_diff:  0.020808684026205275
# CAPTURE!
# profile_diff:  0.013631936107990744
# CAPTURE!
# profile_diff:  0.018210504398909658
# CAPTURE!
# profile_diff:  0.019599252147217604
# CAPTURE!
# profile_diff:  0.011231498704484616
# CAPTURE!
# profile_diff:  0.006532939243263899
# CAPTURE!
# profile_diff:  0.01514823388229172
# CAPTURE!
# profile_diff:  0.01465226577422943
# CAPTURE!
# profile_diff:  0.020830853650387164
# CAPTURE!
# CAN NOT FIND CAPTURE, OPENING NOX MENU
# profile_diff:  0.010361396263618186
# CAPTURE!
# profile_diff:  0.0195969268418412
# CAPTURE!
# profile_diff:  0.018022191716254778
# CAPTURE!
# profile_diff:  0.013468054616335991
# CAPTURE!
# profile_diff:  0.012390875750438277
# CAPTURE!
# profile_diff:  0.011611567333803694
# CAPTURE!
# profile_diff:  0.01321584802683123
# CAPTURE!
# profile_diff:  0.018800679510623978
# CAPTURE!
# profile_diff:  0.01601404407981297
# CAPTURE!
# profile_diff:  0.016361648562705784
# CAPTURE!
# profile_diff:  0.016599288392441625
# CAPTURE!
# profile_diff:  0.012499464545815254
# CAPTURE!
# profile_diff:  0.009648453295235932
# CAPTURE!
# profile_diff:  0.00823266216805212
# CAPTURE!
# profile_diff:  0.012249116009063789
# CAPTURE!
# profile_diff:  0.021929687505039305
# CAPTURE!
# profile_diff:  0.018031855909413606
# CAPTURE!
# profile_diff:  0.010713566103286516
# CAPTURE!
# profile_diff:  0.017482217764488977
# CAPTURE!
# profile_diff:  0.007554655701021817
# CAPTURE!
# profile_diff:  0.012276559305502885
# CAPTURE!
# profile_diff:  0.01197238009525495
# CAPTURE!
# profile_diff:  0.004579694551869149
# CAPTURE!
# profile_diff:  0.01466977368839056
# CAPTURE!
# profile_diff:  0.018869026564180037
# CAPTURE!
# profile_diff:  0.018895670811464114
# CAPTURE!
# profile_diff:  0.009223247108624752
# CAPTURE!
# profile_diff:  0.007554655701021817
# CAPTURE!
# profile_diff:  0.012276559305502885
# CAPTURE!
# profile_diff:  0.011771026682633714
# CAPTURE!
# profile_diff:  0.004622712051216209
# CAPTURE!
# profile_diff:  0.014656788561041051
# CAPTURE!
# profile_diff:  0.018874798001776383
# CAPTURE!
# profile_diff:  0.01918580871471862
# CAPTURE!
# profile_diff:  0.009235709566239477
# CAPTURE!
# profile_diff:  0.010181667081586934
# CAPTURE!
# profile_diff:  0.013340530592521944
# CAPTURE!
# profile_diff:  0.01233949986826916
# CAPTURE!
# profile_diff:  0.010372376611803121
# CAPTURE!
# profile_diff:  0.020729683535176017
# CAPTURE!
# profile_diff:  0.01665806745839818
# CAPTURE!
# profile_diff:  0.017605212349831523
# CAPTURE!
# profile_diff:  0.013114898877168737
# CAPTURE!
# profile_diff:  0.008474276305291543
# CAPTURE!
# profile_diff:  0.011635437112689804
# CAPTURE!
# profile_diff:  0.011796669806038124
# CAPTURE!
# profile_diff:  0.01043983579136093
# CAPTURE!
# profile_diff:  0.01941607953008925
# CAPTURE!
# profile_diff:  0.017713038232994416
# CAPTURE!
# profile_diff:  0.01799814476085282
# CAPTURE!
# profile_diff:  0.012904140955852536
# CAPTURE!
# profile_diff:  0.013402770359498061
# CAPTURE!
# profile_diff:  0.016927549240409685
# CAPTURE!
# profile_diff:  0.008474276305291543
# CAPTURE!
# profile_diff:  0.011635437112689804
# CAPTURE!
# profile_diff:  0.011796669806038124
# CAPTURE!
# profile_diff:  0.01043983579136093
# CAPTURE!
# profile_diff:  0.01941607953008925
# CAPTURE!
# profile_diff:  0.017713038232994416
# CAPTURE!
# profile_diff:  0.01799814476085282
# CAPTURE!
# profile_diff:  0.012904140955852536
# CAPTURE!
# profile_diff:  0.013402770359498061
# CAPTURE!
# profile_diff:  0.015356054060869189
# CAPTURE!
# profile_diff:  0.016927549240409685
# CAPTURE!
# profile_diff:  0.01732374938973554
# CAPTURE!
# profile_diff:  0.015131252139488263
# CAPTURE!
# profile_diff:  0.009542309989122092
# CAPTURE!
# profile_diff:  0.012418382426801142
# CAPTURE!
# profile_diff:  0.014697513982222896
# CAPTURE!
# profile_diff:  0.024713982189802797
# CAPTURE!
# profile_diff:  0.014218766674370442
# CAPTURE!
# profile_diff:  0.017612627791285928
# CAPTURE!
# profile_diff:  0.018617420187580946
# CAPTURE!
# profile_diff:  0.01158502007375658
# CAPTURE!
# profile_diff:  0.012771092487526772
# CAPTURE!
# profile_diff:  0.014368539839241704
# CAPTURE!
# profile_diff:  0.013043357674201315
# CAPTURE!
# profile_diff:  0.007167062228545602
# CAPTURE!
# profile_diff:  0.013695645457129086
# CAPTURE!
# profile_diff:  0.012673425912527299
# CAPTURE!
# profile_diff:  0.005524573583114045
# CAPTURE!
# profile_diff:  0.01891470824972911
# CAPTURE!
# profile_diff:  0.016539745192588263
# CAPTURE!
# profile_diff:  0.0163308317745395
# CAPTURE!
# profile_diff:  0.011076348569361651
# CAPTURE!
# profile_diff:  0.013512030707087036
# CAPTURE!
# profile_diff:  0.017733412901349287
# CAPTURE!
# profile_diff:  0.016922064177274626
# CAPTURE!
# profile_diff:  0.01814112274481087
# CAPTURE!
# profile_diff:  0.011488290220623216
# CAPTURE!
# profile_diff:  0.01092686760296983
# CAPTURE!
# profile_diff:  0.013328214367626713
# CAPTURE!
# profile_diff:  0.010262135232621993
# CAPTURE!
# profile_diff:  0.020220812046778135
# CAPTURE!
# profile_diff:  0.015337871472060966
# CAPTURE!
# profile_diff:  0.020214670929500456
# CAPTURE!
# profile_diff:  0.015433179593765166
# CAPTURE!
# profile_diff:  0.01518354630468165
# CAPTURE!
# profile_diff:  0.019590221647019825
# CAPTURE!
# profile_diff:  0.01818728834265296
# CAPTURE!
# profile_diff:  0.02022630200638878
# CAPTURE!
# profile_diff:  0.013786011026736832
# CAPTURE!
# profile_diff:  0.011603430109507273
# CAPTURE!
# profile_diff:  0.008793529928971519
# CAPTURE!
# profile_diff:  0.014253911403798152
# CAPTURE!
# profile_diff:  0.024656959722051668
# CAPTURE!
# profile_diff:  0.019231826443106968
# CAPTURE!
# profile_diff:  0.010762231845214363
# CAPTURE!
# profile_diff:  0.016860842101968875
# CAPTURE!
# profile_diff:  0.015124765603212725
# CAPTURE!
# profile_diff:  0.012346635572347045
# CAPTURE!
# profile_diff:  0.019103956399872186
# CAPTURE!
# profile_diff:  0.014376056868556298
# CAPTURE!
# profile_diff:  0.00931871844503142
# CAPTURE!
# profile_diff:  0.01303436699185112
# CAPTURE!
# profile_diff:  0.013350010791796554
# CAPTURE!
# profile_diff:  0.0068814201251530946
# CAPTURE!
# profile_diff:  0.017528539124167828
# CAPTURE!
# profile_diff:  0.015782012283144586
# CAPTURE!
# profile_diff:  0.01840570960124477
# CAPTURE!
# profile_diff:  0.01461025439342781
# CAPTURE!
# profile_diff:  0.014151660255421843
# CAPTURE!
# profile_diff:  0.018783339803550233
# CAPTURE!
# profile_diff:  0.016656058208906723
# CAPTURE!
# profile_diff:  0.01740015966653216
# CAPTURE!
# profile_diff:  0.01541811287854031
# CAPTURE!
# profile_diff:  0.01117813435488051
# CAPTURE!
# profile_diff:  0.008246575181336103
# CAPTURE!
# profile_diff:  0.013652570278877809
# CAPTURE!
# profile_diff:  0.024260685703735355
# CAPTURE!
# profile_diff:  0.018470758441991898
# CAPTURE!
# profile_diff:  0.012257711160079435
# CAPTURE!
# profile_diff:  0.016382524397116342
# CAPTURE!
# profile_diff:  0.012524700449541895
# CAPTURE!
# profile_diff:  0.0068950449189658335
# CAPTURE!
# profile_diff:  0.01704846155052648
# CAPTURE!
# profile_diff:  0.010548367279990081
# CAPTURE!
# profile_diff:  0.010365025021054174
# CAPTURE!
# profile_diff:  0.00944751528317931
# CAPTURE!
# profile_diff:  0.011918106118357762
# CAPTURE!
# profile_diff:  0.014298067559470457
# CAPTURE!
# profile_diff:  0.0202787161688406
# CAPTURE!
# profile_diff:  0.011258233916595936
# CAPTURE!
# profile_diff:  0.017871092460711092
# CAPTURE!
# profile_diff:  0.01749221974024861
# CAPTURE!
# profile_diff:  0.005434903636913728
# CAPTURE!
# profile_diff:  0.7166428519337551
# profile_diff:  0.770631098575127
# profile_diff:  0.770631098575127

# %% [markdown]
# # Let's OCR

# %%
# OCRHelper.py 에서 profile_list를 initialize 하려 했으나
# import 와 동시에 profile_list가 eval되어 빈폴더를 load하는 문제가 발생
profile_path = './Screenshots/'
profile_list = glob.glob(profile_path + '*.png')
Players = OH.ocr_profiles(profile_list = profile_list)
# Out:
# 1/170
# 2/170
# 3/170
# KeyError!! : checkt Screenshot_2020-08-23-13-46-44.png
# 4/170
# 5/170
# KeyError!! : checkt Screenshot_2020-08-23-13-46-54.png
# 6/170
# KeyError!! : checkt Screenshot_2020-08-23-13-47-01.png
# 7/170
# 8/170
# 9/170
# 10/170
# 11/170
# 12/170
# 13/170
# 14/170
# 15/170
# 16/170
# 17/170
# KeyError!! : checkt Screenshot_2020-08-23-13-47-48.png
# 18/170
# KeyError!! : checkt Screenshot_2020-08-23-13-47-55.png
# 19/170
# 20/170
# 21/170
# 22/170
# 23/170
# 24/170
# 25/170
# 26/170
# KeyError!! : checkt Screenshot_2020-08-23-13-48-28.png
# 27/170
# 28/170
# 29/170
# 30/170
# 31/170
# 32/170
# 33/170
# KeyError!! : checkt Screenshot_2020-08-23-13-48-53.png
# 34/170
# 35/170
# 36/170
# 37/170
# 38/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-14.png
# 39/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-18.png
# 40/170
# 41/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-25.png
# 42/170
# 43/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-36.png
# 44/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-39.png
# 45/170
# 46/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-47.png
# 47/170
# 48/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-54.png
# 49/170
# KeyError!! : checkt Screenshot_2020-08-23-13-49-58.png
# 50/170
# 51/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-08.png
# 52/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-12.png
# 53/170
# 54/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-19.png
# 55/170
# 56/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-26.png
# 57/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-30.png
# 58/170
# 59/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-41.png
# 60/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-45.png
# 61/170
# KeyError!! : checkt Screenshot_2020-08-23-13-50-48.png
# 62/170
# 63/170
# 64/170
# 65/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-03.png
# 66/170
# 67/170
# 68/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-17.png
# 69/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-21.png
# 70/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-24.png
# 71/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-28.png
# 72/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-32.png
# 73/170
# 74/170
# 75/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-42.png
# 76/170
# 77/170
# 78/170
# KeyError!! : checkt Screenshot_2020-08-23-13-51-57.png
# 79/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-01.png
# 80/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-05.png
# 81/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-08.png
# 82/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-12.png
# 83/170
# 84/170
# 85/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-23.png
# 86/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-26.png
# 87/170
# 88/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-37.png
# 89/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-41.png
# 90/170
# 91/170
# 92/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-51.png
# 93/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-55.png
# 94/170
# KeyError!! : checkt Screenshot_2020-08-23-13-52-59.png
# 95/170
# KeyError!! : checkt Screenshot_2020-08-23-13-53-02.png
# 96/170
# KeyError!! : checkt Screenshot_2020-08-23-13-53-06.png
# 97/170
# 98/170
# 99/170
# KeyError!! : checkt Screenshot_2020-08-23-13-53-17.png
# 100/170
# KeyError!! : checkt Screenshot_2020-08-23-13-53-24.png
# 101/170
# 102/170
# 103/170
# KeyError!! : checkt Screenshot_2020-08-23-13-53-35.png
# 104/170
# 105/170
# 106/170
# KeyError!! : checkt Screenshot_2020-08-23-13-53-45.png
# 107/170
# 108/170
# 109/170
# 110/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-00.png
# 111/170
# 112/170
# 113/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-14.png
# 114/170
# 115/170
# 116/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-25.png
# 117/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-28.png
# 118/170
# 119/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-36.png
# 120/170
# 121/170
# 122/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-47.png
# 123/170
# KeyError!! : checkt Screenshot_2020-08-23-13-54-50.png
# 124/170
# 125/170
# KeyError!! : checkt Screenshot_2020-08-23-13-55-01.png
# 126/170
# 127/170
# 128/170
# 129/170
# 130/170
# 131/170
# 132/170
# 133/170
# KeyError!! : checkt Screenshot_2020-08-23-13-55-30.png
# 134/170
# 135/170
# 136/170
# KeyError!! : checkt Screenshot_2020-08-23-13-55-44.png
# 137/170
# 138/170
# KeyError!! : checkt Screenshot_2020-08-23-13-55-51.png
# 139/170
# 140/170
# KeyError!! : checkt Screenshot_2020-08-23-13-55-58.png
# 141/170
# 142/170
# 143/170
# 144/170
# KeyError!! : checkt Screenshot_2020-08-23-13-56-13.png
# 145/170
# 146/170
# 147/170
# 148/170
# 149/170
# 150/170
# KeyError!! : checkt Screenshot_2020-08-23-13-56-38.png
# 151/170
# 152/170
# KeyError!! : checkt Screenshot_2020-08-23-13-56-45.png
# 153/170
# 154/170
# 155/170
# KeyError!! : checkt Screenshot_2020-08-23-13-56-56.png
# 156/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-00.png
# 157/170
# 158/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-07.png
# 159/170
# 160/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-17.png
# 161/170
# 162/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-24.png
# 163/170
# 164/170
# 165/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-35.png
# 166/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-39.png
# 167/170
# 168/170
# KeyError!! : checkt Screenshot_2020-08-23-13-57-46.png
# 169/170
# 170/170
# KeyError!! : checkt Screenshot_2020-08-23-14-01-07.png

# %%
Players
# Out:
# {32963004: 폭풍검,
#  32877496: 꼬따발,
#  32889199: ,
#  32930660: 폭풍을지,
#  35394960: ,
#  32901137: ,
#  32869646: 꽃돌,
#  36654814: 뉴비,
#  32864188: 찬사,
#  32965304: 혈마,
#  32863931: 빈도,
#  34047819: 타우렝,
#  36954744: 불곰,
#  32836063: Big Sish,
#  31851240: Ro Downey Jr,
#  32931643: 폭풍JOKER,
#  34056859: ,
#  34047107: ,
#  32853239: 폭풍캠핑,
#  34231456: 유선,
#  32957115: 잘하거나자라거나,
#  32819832: 액트,
#  34000149: 초록별공공,
#  34229105: 폭풍돌팸황충,
#  33003834: 노마,
#  34012293: ,
#  32944092: 유로,
#  32863540: 우강다,
#  32958563: 와이핀,
#  34231316: 안감독,
#  39738082: 수정,
#  32858136: 폭풍청산,
#  33627113: ,
#  32884774: 기범아빠,
#  32914780: 방범대원,
#  32853536: 포유,
#  32921102: 6072리,
#  33990290: ,
#  48848954: ,
#  32897649: 유감토깽이,
#  32922320: ,
#  32847630: ,
#  32932218: ,
#  32852263: 빡돌,
#  32933551: 똘돌,
#  32844701: ,
#  32956316: ,
#  32849136: 유니파더손,
#  33272129: ,
#  32961107: ,
#  32878898: ,
#  32916567: 민준하은,
#  32858679: 에이치피,
#  32900066: 네다바이,
#  37765819: ,
#  45038942: 지라리풍풍,
#  32854442: 95판다곰,
#  32916955: ,
#  32898999: ,
#  32906929: ,
#  32862413: ,
#  32846768: ,
#  32890539: 헌터,
#  32848980: 내가너좀좋아하면안되냐,
#  34045650: ,
#  32883074: ,
#  33095971: 아버,
#  31747335: ,
#  32913454: ,
#  34073039: 이순신 강,
#  33571072: 나도함,
#  31777013: ,
#  38848917: ,
#  32840349: ,
#  32873835: ,
#  34855695: ,
#  32903451: 국제공항,
#  33980638: 타도철수,
#  32952610: ,
#  32930456: ,
#  32901612: 을지로삼가,
#  32852827: 좋은아침,
#  32907970: ,
#  32885735: 복돌이90,
#  32893093: WaLeeD,
#  31743642: ,
#  33154600: 악돌,
#  32902606: 구르마,
#  32873061: 아스라,
#  32873393: ,
#  32924821: kensin83,
#  32886907: 최Garen,
#  32873301: ,
#  32930996: 여왕라니아,
#  33161683: 시미켄,
#  35622285: ,
#  31785055: ,
#  33244924: teto1,
#  32854342: ,
#  32879062: DEATH PROOF,
#  33376297: 강씨아저씨,
#  34018291: ,
#  32960936: ,
#  32894351: Jenny888,
#  32873085: ,
#  32858772: 신식빠빠롱,
#  32886708: 카니쟈,
#  32913745: 이실로브,
#  32888795: 괴짜영웅,
#  32948675: 조시안서,
#  32033026: 향료수,
#  32939213: 션돌,
#  33999480: ,
#  32902261: 약먹,
#  32867811: 킨잘,
#  36244443: ,
#  36946100: 테누토,
#  34057627: ,
#  32939705: 황소,
#  36243607: ,
#  43290699: 펭러브,
#  34115436: 서태웅,
#  32968225: 에스페란쟈,
#  32874191: ,
#  32856088: 김초심,
#  32896806: 단오쿤,
#  32949515: 물돌,
#  34049952: 물따귀,
#  32914945: 율곡이이,
#  33074237: ,
#  32885285: 폭풍날먹,
#  32933976: ,
#  32892748: 빠삐장군,
#  32909486: 부라리두짝,
#  32853487: ,
#  31740246: ,
#  32863456: fireworkcorki,
#  32885683: ,
#  34000984: 감금물,
#  32881706: ,
#  33968960: 어흥비,
#  3283858: }

# %% [markdown]
# # Convert to DataFrame

# %%
df = OH.Players2df(Players)
df
# Out:
#            ID  name      power      kill                                path
# 0    32963004   폭풍검  114103451  61069693  Screenshot_2020-08-23-13-46-35.png
# 1    32877496   꼬따발   54232517  12235007  Screenshot_2020-08-23-13-46-39.png
# 2    32889199         41295667   5323050  Screenshot_2020-08-23-13-46-44.png
# 3    32930660  폭풍을지   53717839   4438977  Screenshot_2020-08-23-13-46-49.png
# 4    35394960         40330840   3352592  Screenshot_2020-08-23-13-46-54.png
# ..        ...   ...        ...       ...                                 ...
# 137  32885683         45463405   9073460  Screenshot_2020-08-23-13-57-39.png
# 138  34000984   감금물   40961985   2353762  Screenshot_2020-08-23-13-57-43.png
# 139  32881706         41535231   7704250  Screenshot_2020-08-23-13-57-46.png
# 140  33968960   어흥비   37485365  15803611  Screenshot_2020-08-23-13-58-30.png
# 141   3283858         41015970  10434915  Screenshot_2020-08-23-14-01-07.png
#
# [142 rows x 5 columns]

# %% [markdown]
# # Save as xlsx

# %%
dt = datetime.datetime.now()
output_name = '-'.join([str(dt.year), str(dt.month), str(dt.day)])
output_name = 'ERN-' + output_name
df.to_excel(output_name + '.xlsx', index=False)

# %% [markdown]
# # Expand id2name
#
# OCR후 저장된 xlsx file(e.g. df.to_excel(output_name + '.xlsx', index=False))를 open합니다. name이 빠져있는 id를 체크하여 name을 채워넣습니다. 그 후 다음 코드를 실행하세요.

# %%
id2name = OH.load_id2name('PALO-2020-7-21.xlsx', 
                          id2name=OH.load_id2name('id2name.xlsx'))
id2name

# %%
OH.save_id2name(id2name)
